# %% [markdown]
# <a href="https://colab.research.google.com/github/arulthus-bot/data-Analysis-using-python--project/blob/main/Untitled_day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def calculate_average(a, b, c):
    return (a + b + c) / 3

try:
    a = int(input("Enter 1st number: "))
    b = int(input("Enter 2nd number: "))
    c = int(input("Enter 3rd number: "))

    print("calculate_average =", calculate_average(a, b, c))

except ValueError:
    print("Invalid Input")
# Out:
# Enter 1st number: 70
# Enter 2nd number: 80
# Enter 3rd number: 60
# calculate_average = 70.0
